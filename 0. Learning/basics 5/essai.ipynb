# %%
import pandas as pd
import numpy as np

# %%
raw_data = pd.read_csv("nutrition_2023_households.csv")
# Out:
#                                 case_id  closed               date_closed  \
# 0  82b0b868-f1c9-4cd5-9601-579af1e9a4aa   False                       NaN
# 1      7deefb25c15e402db19e26e140a64517    True  2023-08-16T20:55:58.743Z
# 2      df9280e54e9947d5a870fa9270aa9c76    True  2023-08-16T20:55:58.781Z
# 3      689719e37a3c43c38c5af84b4b2039c4    True  2023-08-16T20:55:58.788Z
# 4      2bfc8a8ecf4a4fd99f717f9c0515c503    True  2023-08-16T20:55:58.975Z
#
#                           opened_by  client_code client_gender  \
# 0  d1509f085907468790570995cf877e94          NaN         homme
# 1  4ef1428cc32608cf3ff19fd9fe2b3ec4      24881.0         femme
# 2  4ef1428cc32608cf3ff19fd9fe2b3ec4      48125.0         femme
# 3  4ef1428cc32608cf3ff19fd9fe2b3ec4      57739.0         femme
# 4  4ef1428cc32608cf3ff19fd9fe2b3ec4      90363.0         femme
#
#         client_name  client_phone control_myagro  country  ...  \
# 0             aliou   777301752.0        control  Senegal  ...
# ...

# %%
raw_data.head()

# %%
raw_data.columns
# Out:
# Index(['case_id', 'closed', 'date_closed', 'opened_by', 'client_code',
#        'client_gender', 'client_name', 'client_phone', 'control_myagro',
#        'country', 'date_identifie', 'date_opened', 'district', 'eligible',
#        'eligible_review', 'gps', 'latitude', 'longitude', 'hs_compost',
#        'hs_farming_is_main_income_source', 'hs_hectares_cultivated',
#        'hs_household_members', 'hs_inputs_on_other_crop', 'hs_livestock',
#        'hs_main_crop', 'hs_main_crop_other', 'hs_main_income_source',
#        'hs_ml_ppi_children_under_11', 'hs_ml_ppi_iron', 'hs_ml_ppi_motorcycle',
#        'hs_ml_ppi_radio', 'hs_ml_ppi_roof_material', 'hs_ml_ppi_toilet',
#        'hs_ml_ppi_tv', 'hs_ml_ppi_walls_material', 'hs_ml_ppi_water_source',
#        'hs_other_livestock', 'hs_package_type', 'hs_participant_gender',
#        'hs_participant_is_client', 'hs_participant_is_respondant',
#        'hs_remittance', 'hs_sn_ppi_children_6_and_under',
# ...

# %%
raw_data.dtypes
# Out:
# case_id           object
# closed              bool
# date_closed       object
# opened_by         object
# client_code      float64
#                   ...
# village_code      object
# zone              object
# surveyor_name     object
# site_code         object
# username          object
# Length: 74, dtype: object

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3707 entries, 0 to 3706
# Data columns (total 74 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   case_id                               3707 non-null   object
#  1   closed                                3707 non-null   bool
#  2   date_closed                           425 non-null    object
#  3   opened_by                             3707 non-null   object
#  4   client_code                           1997 non-null   float64
#  5   client_gender                         3706 non-null   object
#  6   client_name                           3706 non-null   object
#  7   client_phone                          3706 non-null   float64
#  8   control_myagro                        3707 non-null   object
#  9   country                               3707 non-null   object
#  10  date_identifie                        1710 non-null   object
# ...

# %%
raw_data.describe(include="all")
# Out:
#                                      case_id closed               date_closed  \
# count                                   3707   3707                       425
# unique                                  3707      2                       425
# top     82b0b868-f1c9-4cd5-9601-579af1e9a4aa  False  2023-08-16T20:55:58.743Z
# freq                                       1   3282                         1
# mean                                     NaN    NaN                       NaN
# std                                      NaN    NaN                       NaN
# min                                      NaN    NaN                       NaN
# 25%                                      NaN    NaN                       NaN
# 50%                                      NaN    NaN                       NaN
# 75%                                      NaN    NaN                       NaN
# max                                      NaN    NaN                       NaN
#
# ...

# %%
[col for col in raw_data if "hs_" in col]
# Out:
# ['hs_compost',
#  'hs_farming_is_main_income_source',
#  'hs_hectares_cultivated',
#  'hs_household_members',
#  'hs_inputs_on_other_crop',
#  'hs_livestock',
#  'hs_main_crop',
#  'hs_main_crop_other',
#  'hs_main_income_source',
#  'hs_ml_ppi_children_under_11',
#  'hs_ml_ppi_iron',
#  'hs_ml_ppi_motorcycle',
#  'hs_ml_ppi_radio',
#  'hs_ml_ppi_roof_material',
#  'hs_ml_ppi_toilet',
#  'hs_ml_ppi_tv',
#  'hs_ml_ppi_walls_material',
#  'hs_ml_ppi_water_source',
#  'hs_other_livestock',
#  'hs_package_type',
#  'hs_participant_gender',
#  'hs_participant_is_client',
#  'hs_participant_is_respondant',
#  'hs_remittance',
#  'hs_sn_ppi_children_6_and_under',
#  'hs_sn_ppi_clothing_last_30_days',
#  'hs_sn_ppi_cows',
#  'hs_sn_ppi_fan',
#  'hs_sn_ppi_gas',
#  'hs_sn_ppi_head_of_household_educated',
#  'hs_sn_ppi_roof_material',
#  'hs_sn_ppi_table',
#  'hs_subsidies',
#  'hs_used_fertilizer',
#  'hs_which_livestock',
#  'hs_working_adults',
#  'hs_working_adults_ag']

# %%
ppi_df = raw_data[col_ppi]

# %%
ppi_df.head()
# Out:
#    hs_ml_ppi_children_under_11 hs_ml_ppi_iron hs_ml_ppi_motorcycle  \
# 0                          NaN            NaN                  NaN
# 1                          NaN            NaN                  NaN
# 2                          NaN            NaN                  NaN
# 3                          NaN            NaN                  NaN
# 4                          NaN            NaN                  NaN
#
#   hs_ml_ppi_radio hs_ml_ppi_roof_material hs_ml_ppi_toilet hs_ml_ppi_tv  \
# 0             NaN                     NaN              NaN          NaN
# 1             NaN                     NaN              NaN          NaN
# 2             NaN                     NaN              NaN          NaN
# 3             NaN                     NaN              NaN          NaN
# 4             NaN                     NaN              NaN          NaN
#
#   hs_ml_ppi_walls_material hs_ml_ppi_water_source  \
# 0                      NaN                    NaN
# ...

# %%
col_ppi = [col for col in list(raw_data.columns) if "ppi" in col]

# %%
[col for col in raw_data if "hs_" in col]
# Out:
# ['hs_compost',
#  'hs_farming_is_main_income_source',
#  'hs_hectares_cultivated',
#  'hs_household_members',
#  'hs_inputs_on_other_crop',
#  'hs_livestock',
#  'hs_main_crop',
#  'hs_main_crop_other',
#  'hs_main_income_source',
#  'hs_ml_ppi_children_under_11',
#  'hs_ml_ppi_iron',
#  'hs_ml_ppi_motorcycle',
#  'hs_ml_ppi_radio',
#  'hs_ml_ppi_roof_material',
#  'hs_ml_ppi_toilet',
#  'hs_ml_ppi_tv',
#  'hs_ml_ppi_walls_material',
#  'hs_ml_ppi_water_source',
#  'hs_other_livestock',
#  'hs_package_type',
#  'hs_participant_gender',
#  'hs_participant_is_client',
#  'hs_participant_is_respondant',
#  'hs_remittance',
#  'hs_sn_ppi_children_6_and_under',
#  'hs_sn_ppi_clothing_last_30_days',
#  'hs_sn_ppi_cows',
#  'hs_sn_ppi_fan',
#  'hs_sn_ppi_gas',
#  'hs_sn_ppi_head_of_household_educated',
#  'hs_sn_ppi_roof_material',
#  'hs_sn_ppi_table',
#  'hs_subsidies',
#  'hs_used_fertilizer',
#  'hs_which_livestock',
#  'hs_working_adults',
#  'hs_working_adults_ag']

# %%
c = "hs_compost"
c[:3]
# Out:
# 'hs_'

# %%
[col for col in raw_data if col[0:3] == 'hs_']
# Out:
# ['hs_compost',
#  'hs_farming_is_main_income_source',
#  'hs_hectares_cultivated',
#  'hs_household_members',
#  'hs_inputs_on_other_crop',
#  'hs_livestock',
#  'hs_main_crop',
#  'hs_main_crop_other',
#  'hs_main_income_source',
#  'hs_ml_ppi_children_under_11',
#  'hs_ml_ppi_iron',
#  'hs_ml_ppi_motorcycle',
#  'hs_ml_ppi_radio',
#  'hs_ml_ppi_roof_material',
#  'hs_ml_ppi_toilet',
#  'hs_ml_ppi_tv',
#  'hs_ml_ppi_walls_material',
#  'hs_ml_ppi_water_source',
#  'hs_other_livestock',
#  'hs_package_type',
#  'hs_participant_gender',
#  'hs_participant_is_client',
#  'hs_participant_is_respondant',
#  'hs_remittance',
#  'hs_sn_ppi_children_6_and_under',
#  'hs_sn_ppi_clothing_last_30_days',
#  'hs_sn_ppi_cows',
#  'hs_sn_ppi_fan',
#  'hs_sn_ppi_gas',
#  'hs_sn_ppi_head_of_household_educated',
#  'hs_sn_ppi_roof_material',
#  'hs_sn_ppi_table',
#  'hs_subsidies',
#  'hs_used_fertilizer',
#  'hs_which_livestock',
#  'hs_working_adults',
#  'hs_working_adults_ag']

# %%
[col for col in raw_data if col[0:3] == 'hs_']
# Out:
# ['hs_compost',
#  'hs_farming_is_main_income_source',
#  'hs_hectares_cultivated',
#  'hs_household_members',
#  'hs_inputs_on_other_crop',
#  'hs_livestock',
#  'hs_main_crop',
#  'hs_main_crop_other',
#  'hs_main_income_source',
#  'hs_ml_ppi_children_under_11',
#  'hs_ml_ppi_iron',
#  'hs_ml_ppi_motorcycle',
#  'hs_ml_ppi_radio',
#  'hs_ml_ppi_roof_material',
#  'hs_ml_ppi_toilet',
#  'hs_ml_ppi_tv',
#  'hs_ml_ppi_walls_material',
#  'hs_ml_ppi_water_source',
#  'hs_other_livestock',
#  'hs_package_type',
#  'hs_participant_gender',
#  'hs_participant_is_client',
#  'hs_participant_is_respondant',
#  'hs_remittance',
#  'hs_sn_ppi_children_6_and_under',
#  'hs_sn_ppi_clothing_last_30_days',
#  'hs_sn_ppi_cows',
#  'hs_sn_ppi_fan',
#  'hs_sn_ppi_gas',
#  'hs_sn_ppi_head_of_household_educated',
#  'hs_sn_ppi_roof_material',
#  'hs_sn_ppi_table',
#  'hs_subsidies',
#  'hs_used_fertilizer',
#  'hs_which_livestock',
#  'hs_working_adults',
#  'hs_working_adults_ag']
