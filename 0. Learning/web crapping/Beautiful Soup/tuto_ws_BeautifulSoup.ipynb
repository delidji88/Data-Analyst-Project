# %% [markdown]
# # Tuto Web Scrapping - BeautifulSoup

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
wttj_url = 'https://www.welcometothejungle.com/fr/companies/eig/jobs/data-analyst-stagiaire-en-fin-d-etudes_courbevoie?q=0d8b7fe012cd791de3aaa3db2aaa579a&o=0f0b6983-97a0-47b1-ac0e-8175ee91389c'
page = requests.get(wttj_url)

soup = bs(page.content)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="fr">
#  <head>
#   <script type="text/javascript">
# ...
